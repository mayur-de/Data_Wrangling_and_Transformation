# %% [markdown]
# ## **Import libraries and data**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Task: Preprocess the data for further analysis**

# %%
# Read data

data = pd.read_excel("Invoices-with-Merged-Categories-and-Merged-Amounts.xlsx")
data
# Out:
#          Order ID                                    Category  \
# 0  CA-2011-167199  Binders | Art | Phones | Fasteners | Paper
# 1  CA-2011-149020                 Office Supplies | Furniture
# 2  CA-2011-131905   Office Supplies | Technology | Technology
# 3  CA-2011-127614              Accessories | Tables | Binders
#
#                                     Amount
# 0  609.98 | 5.48 | 391.98 | 755.96 | 31.12
# 1                             2.98 | 51.94
# 2                   7.2 | 42.0186 | 42.035
# 3                 234.45 | 1256.22 | 17.46

# %% [markdown]
# ### **The issues include:**
#
# - Multiple categories in one cell: Categories are combined in a single cell, separated by |.
# - Multiple amounts in one cell: Corresponding amounts are also combined in a single cell, separated by |.
# - Misalignment: Each category must align with its corresponding amount.
# - Duplicates: Some categories are repeated in a single row

# %% [markdown]
# ### **Solution:**
# - Split the Category column on `|` to get individual categories.
# - Split the Amount column on `|` to get individual amounts.
# - Create a row for each Order ID with its corresponding Category and Amount.
# - Ensure the Amount column is in a numeric format for further analysis.
# - Operations regarding duplicated categories.

# %%
# Split columns

# We will use assign 
# Split the data in box by "|" and assign it to existing column/plcae

data= data.assign(Category = data['Category'].str.split("|"), 
                  Amount = data['Amount'].str.split("|"))

# Explode values
# explode each row into column for "Category" and similarly "Amount"
 
data = data.explode("Category").explode("Amount")
data
# Out:
#          Order ID          Category     Amount
# 0  CA-2011-167199          Binders     609.98
# 0  CA-2011-167199          Binders       5.48
# 0  CA-2011-167199          Binders     391.98
# 0  CA-2011-167199          Binders     755.96
# 0  CA-2011-167199          Binders       31.12
# 0  CA-2011-167199              Art     609.98
# 0  CA-2011-167199              Art       5.48
# 0  CA-2011-167199              Art     391.98
# 0  CA-2011-167199              Art     755.96
# 0  CA-2011-167199              Art       31.12
# 0  CA-2011-167199           Phones     609.98
# 0  CA-2011-167199           Phones       5.48
# 0  CA-2011-167199           Phones     391.98
# 0  CA-2011-167199           Phones     755.96
# 0  CA-2011-167199           Phones       31.12
# 0  CA-2011-167199        Fasteners     609.98
# 0  CA-2011-167199        Fasteners       5.48
# 0  CA-2011-167199        Fasteners     391.98
# 0  CA-2011-167199        Fasteners     755.96
# 0  CA-2011-167199        Fasteners       31.12
# 0  CA-2011-167199             Paper    609.98
# 0  CA-2011-167199             Paper      5.48
# 0  CA-2011-167199             Paper    391.98
# 0  CA-2011-167199             Paper    755.96
# 0  CA-2011-167199             Paper      31.12
# 1  CA-2011-149020  Office Supplies       2.98
# 1  CA-2011-149020  Office Supplies       51.94
# 1  CA-2011-149020         Furniture      2.98
# 1  CA-2011-149020         Furniture      51.94
# 2  CA-2011-131905  Office Supplies        7.2
# 3  CA-2011-127614           Tables    234.4500
# 3  CA-2011-127614           Tables   1256.2200
# 3  CA-2011-127614           Tables     17.4600
# 3  CA-2011-127614           Binders   234.4500
# 3  CA-2011-127614           Binders  1256.2200
# 3  CA-2011-127614           Binders    17.4600

# %%
# Reset Index

data.reset_index(drop= True, inplace= True)
data
# Out:
#           Order ID          Category     Amount
# 0   CA-2011-167199          Binders    609.9800
# 1   CA-2011-167199          Binders      5.4800
# 2   CA-2011-167199          Binders    391.9800
# 3   CA-2011-167199          Binders    755.9600
# 4   CA-2011-167199          Binders     31.1200
# 5   CA-2011-167199              Art    609.9800
# 6   CA-2011-167199              Art      5.4800
# 7   CA-2011-167199              Art    391.9800
# 8   CA-2011-167199              Art    755.9600
# 9   CA-2011-167199              Art     31.1200
# 10  CA-2011-167199           Phones    609.9800
# 11  CA-2011-167199           Phones      5.4800
# 12  CA-2011-167199           Phones    391.9800
# 13  CA-2011-167199           Phones    755.9600
# 14  CA-2011-167199           Phones     31.1200
# 15  CA-2011-167199        Fasteners    609.9800
# 16  CA-2011-167199        Fasteners      5.4800
# 17  CA-2011-167199        Fasteners    391.9800
# 18  CA-2011-167199        Fasteners    755.9600
# 19  CA-2011-167199        Fasteners     31.1200
# 20  CA-2011-167199             Paper   609.9800
# 21  CA-2011-167199             Paper     5.4800
# 22  CA-2011-167199             Paper   391.9800
# 23  CA-2011-167199             Paper   755.9600
# 24  CA-2011-167199             Paper    31.1200
# 25  CA-2011-149020  Office Supplies      2.9800
# 26  CA-2011-149020  Office Supplies     51.9400
# 27  CA-2011-149020         Furniture     2.9800
# 28  CA-2011-149020         Furniture    51.9400
# 29  CA-2011-131905  Office Supplies      7.2000
# 30  CA-2011-131905  Office Supplies     42.0186
# 31  CA-2011-131905  Office Supplies     42.0350
# 32  CA-2011-131905       Technology      7.2000
# 33  CA-2011-131905       Technology     42.0186
# 34  CA-2011-131905       Technology     42.0350
# 35  CA-2011-131905        Technology     7.2000
# 36  CA-2011-131905        Technology    42.0186
# 37  CA-2011-131905        Technology    42.0350
# 38  CA-2011-127614      Accessories    234.4500
# 39  CA-2011-127614      Accessories   1256.2200
# 40  CA-2011-127614      Accessories     17.4600
# 41  CA-2011-127614           Tables    234.4500
# 42  CA-2011-127614           Tables   1256.2200
# 43  CA-2011-127614           Tables     17.4600
# 44  CA-2011-127614           Binders   234.4500
# 45  CA-2011-127614           Binders  1256.2200
# 46  CA-2011-127614           Binders    17.4600

# %%
# Check duplicated

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Note:** There aren't any duplicated values in the dataset

# %%
# Save the transformed sheet in the original datasheet

with pd.ExcelWriter("Invoices-with-Merged-Categories-and-Merged-Amounts.xlsx", engine= 'openpyxl', mode='a') as writer:
    data.to_excel(writer, sheet_name= "Transformed_data", index= False)
